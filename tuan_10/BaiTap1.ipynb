# %%
import matplotlib.pyplot as plt
from skimage import io, color

# %%
# Load ảnh
image = plt.imread('E:\\NAM_3\\HOC_KY_6\\TT XU LY ANH\\BT_05_04_2023\\DEN_3MAU.jpg')
plt.imshow(image)
plt.axis('off')
# Out:
# (-0.5, 1919.5, 2559.5, -0.5)

# %%
# Chuyển ảnh từ RGB sang LAB
grayscale = color.rgb2gray(image)
type(grayscale)
plt.imshow(grayscale,cmap='gray')
plt.axis('off')
# Out:
# (-0.5, 1919.5, 2559.5, -0.5)

# %%
# Obtaining the red values of the image
red = image[:, :, 0]
plt.imshow(red,cmap='gray')
plt.title('Red')
plt.axis('off')
# Out:
# (-0.5, 1919.5, 2559.5, -0.5)

# %%
# Load ảnh
image = plt.imread('E:\\NAM_3\\HOC_KY_6\\TT XU LY ANH\\BT_05_04_2023\\DEN_3MAU.jpg')

# Chuyển ảnh từ RGB sang LAB
grayscale = color.rgb2gray(image)
type(image)

# Obtaining the red values of the image
red = image[:, :, 0]

# Obtaining the green values of the image
green = image[:, :, 1]

# Obtaining the blue values of the image
blue = image[:, :, 2]
plt.figure()
plt.imshow(red)
plt.title('Red')
plt.axis('off')

plt.figure()
plt.imshow(green)
plt.title('Green')
plt.axis('off')

plt.figure()
plt.imshow(blue)
plt.title('Blue')
plt.axis('off')
plt.show()
